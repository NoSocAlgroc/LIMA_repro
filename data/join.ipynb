# %%
import pandas as pd
import numpy as np

# %%
years=list(range(2020,2025))
months=list(range(1,13))

dataDir="data/"

# %%
year=2020
month=1
fileName=f"On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_{year}_{month}.csv"
df=pd.read_csv("data/"+fileName,low_memory=False)

# %%
typeMap={np.dtypes.Int64DType():'Integer',np.dtypes.Float64DType():'Double',np.dtypes.ObjectDType():'String'}
cols=list(range(56))
columns=df.columns[cols]
newColumns=[columns[i]+f"({typeMap[t]})" for i,t in enumerate(df.dtypes.iloc[cols]) ]

# %%
dfs=[]
for year in years[:1]: 
    for month in months[:3]:
        fileName=f"On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_{year}_{month}.csv"
        df=pd.read_csv("data/"+fileName,low_memory=False)
        df=df[columns]
        df.rename(columns=dict(zip(columns, newColumns)),inplace=True)
        dfs.append(df)

# %%
df=pd.concat(dfs,ignore_index=True)
df
# Out:
#          Year(Integer)  Quarter(Integer)  Month(Integer)  DayofMonth(Integer)  \
# 0                 2020                 1               1                   17
# 1                 2020                 1               1                   18
# 2                 2020                 1               1                   19
# 3                 2020                 1               1                   20
# 4                 2020                 1               1                   21
# ...                ...               ...             ...                  ...
# 1829838           2020                 1               3                    1
# 1829839           2020                 1               3                    1
# 1829840           2020                 1               3                    1
# 1829841           2020                 1               3                    1
# 1829842           2020                 1               3                    1
#
#          DayOfWeek(Integer) FlightDate(String) Reporting_Airline(String)  \
# 0                         5         2020-01-17                        B6
# 1                         6         2020-01-18                        B6
# 2                         7         2020-01-19                        B6
# 3                         1         2020-01-20                        B6
# 4                         2         2020-01-21                        B6
# ...                     ...                ...                       ...
# 1829838                   7         2020-03-01                        UA
# 1829839                   7         2020-03-01                        UA
# 1829840                   7         2020-03-01                        UA
# 1829841                   7         2020-03-01                        UA
# 1829842                   7         2020-03-01                        UA
#
#          DOT_ID_Reporting_Airline(Integer)  \
# 0                                    20409
# 1                                    20409
# 2                                    20409
# 3                                    20409
# 4                                    20409
# ...                                    ...
# 1829838                              19977
# 1829839                              19977
# 1829840                              19977
# 1829841                              19977
# 1829842                              19977
#
#         IATA_CODE_Reporting_Airline(String) Tail_Number(String)  ...  \
# 0                                        B6              N661JB  ...
# 1                                        B6              N584JB  ...
# 2                                        B6              N662JB  ...
# 3                                        B6              N784JB  ...
# 4                                        B6              N784JB  ...
# ...                                     ...                 ...  ...
# 1829838                                  UA              N776UA  ...
# 1829839                                  UA              N779UA  ...
# 1829840                                  UA              N79279  ...
# 1829841                                  UA              N79279  ...
# 1829842                                  UA              N17105  ...
#
#          ArrTimeBlk(String)  Cancelled(Double)  CancellationCode(String)  \
# 0                 2200-2259                0.0                       NaN
# 1                 2200-2259                0.0                       NaN
# 2                 2200-2259                0.0                       NaN
# 3                 2200-2259                0.0                       NaN
# 4                 2200-2259                0.0                       NaN
# ...                     ...                ...                       ...
# 1829838           1900-1959                0.0                       NaN
# 1829839           1800-1859                0.0                       NaN
# 1829840           0800-0859                0.0                       NaN
# 1829841           0900-0959                0.0                       NaN
# 1829842           0900-0959                0.0                       NaN
#
#          Diverted(Double) CRSElapsedTime(Double) ActualElapsedTime(Double)  \
# 0                     0.0                  169.0                     172.0
# 1                     0.0                  169.0                     174.0
# 2                     0.0                  169.0                     156.0
# 3                     0.0                  169.0                     180.0
# 4                     0.0                  169.0                     163.0
# ...                   ...                    ...                       ...
# 1829838               0.0                  470.0                     462.0
# 1829839               0.0                  425.0                     417.0
# 1829840               0.0                   41.0                      39.0
# 1829841               0.0                   40.0                      36.0
# 1829842               0.0                  314.0                     321.0
#
#         AirTime(Double)  Flights(Double) Distance(Double)  \
# 0                 151.0              1.0           1133.0
# 1                 147.0              1.0           1133.0
# 2                 139.0              1.0           1133.0
# 3                 140.0              1.0           1133.0
# 4                 147.0              1.0           1133.0
# ...                 ...              ...              ...
# 1829838           435.0              1.0           3801.0
# 1829839           400.0              1.0           3801.0
# 1829840            24.0              1.0            129.0
# 1829841            24.0              1.0            129.0
# 1829842           296.0              1.0           2486.0
#
#          DistanceGroup(Integer)
# 0                             5
# 1                             5
# 2                             5
# 3                             5
# 4                             5
# ...                         ...
# 1829838                      11
# 1829839                      11
# 1829840                       1
# 1829841                       1
# 1829842                      10
#
# [1829843 rows x 56 columns]

# %%
df.to_csv("flights.csv",index=False)

# %%
list(df.dtypes)
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64')]

# %%
df.head()
# Out:
#    Year(Integer)  Quarter(Integer)  Month(Integer)  DayofMonth(Integer)  \
# 0           2020                 1               1                   17
# 1           2020                 1               1                   18
# 2           2020                 1               1                   19
# 3           2020                 1               1                   20
# 4           2020                 1               1                   21
#
#    DayOfWeek(Integer) FlightDate(String) Reporting_Airline(String)  \
# 0                   5         2020-01-17                        B6
# 1                   6         2020-01-18                        B6
# 2                   7         2020-01-19                        B6
# 3                   1         2020-01-20                        B6
# 4                   2         2020-01-21                        B6
#
#    DOT_ID_Reporting_Airline(Integer) IATA_CODE_Reporting_Airline(String)  \
# 0                              20409                                  B6
# 1                              20409                                  B6
# 2                              20409                                  B6
# 3                              20409                                  B6
# 4                              20409                                  B6
#
#   Tail_Number(String)  ...  ArrTimeBlk(String)  Cancelled(Real)  \
# 0              N661JB  ...           2200-2259              0.0
# 1              N584JB  ...           2200-2259              0.0
# 2              N662JB  ...           2200-2259              0.0
# 3              N784JB  ...           2200-2259              0.0
# 4              N784JB  ...           2200-2259              0.0
#
#    CancellationCode(String)  Diverted(Real) CRSElapsedTime(Real)  \
# 0                       NaN             0.0                169.0
# 1                       NaN             0.0                169.0
# 2                       NaN             0.0                169.0
# 3                       NaN             0.0                169.0
# 4                       NaN             0.0                169.0
#
#   ActualElapsedTime(Real) AirTime(Real)  Flights(Real) Distance(Real)  \
# 0                   172.0         151.0            1.0         1133.0
# 1                   174.0         147.0            1.0         1133.0
# 2                   156.0         139.0            1.0         1133.0
# 3                   180.0         140.0            1.0         1133.0
# 4                   163.0         147.0            1.0         1133.0
#
#    DistanceGroup(Integer)
# 0                       5
# 1                       5
# 2                       5
# 3                       5
# 4                       5
#
# [5 rows x 56 columns]
